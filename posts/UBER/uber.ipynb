# %% [markdown]
# ---
# title: "data_analysis_uber"
# author: "Taebum Eom"
# date: "2023-05-30"
# date-format: "YYYY/MM/DD"
# categories: [Data-Mining, GeoPandas]
# title-block-banner: false
# page-layout: full
# image: "h3.png"
# ---

# %% [markdown]
# > data_analysis_uber

# %%
import matplotlib.pyplot as plt
from collections import Counter
import pydeck as pdk
import pandas as pd
from h3 import h3

# %%
H3_HEX_DATA = "https://raw.githubusercontent.com/visgl/deck.gl-data/master/website/sf.h3cells.json"

df = pd.read_json(H3_HEX_DATA)

# Define a layer to display on a map
layer = pdk.Layer(
    "H3HexagonLayer",
    df,
    pickable=True,
    stroked=True,
    filled=True,
    extruded=False,
    get_hexagon="hex",
    get_fill_color="[255 - count, 255, count]",
    get_line_color=[255, 255, 255],
    line_width_min_pixels=2,
)

# Set the viewport location
view_state = pdk.ViewState(latitude=37.7749295, longitude=-122.4194155, zoom=10, bearing=0, pitch=30)


# Render
r = pdk.Deck(layers=[layer], initial_view_state=view_state, tooltip={"text": "Count: {count}"})
r
# Out:
# {
#   "initialViewState": {
#     "bearing": 0,
#     "latitude": 37.7749295,
#     "longitude": -122.4194155,
#     "pitch": 30,
#     "zoom": 10
#   },
#   "layers": [
#     {
#       "@@type": "H3HexagonLayer",
#       "data": [
#         {
#           "count": 96,
#           "hex": "88283082b9fffff"
#         },
#         {
#           "count": 534,
#           "hex": "8828308281fffff"
#         },
#         {
#           "count": 36,
#           "hex": "88283082d7fffff"
#         },
#         {
#           "count": 297,
#           "hex": "88283082c1fffff"
#         },
#         {
#           "count": 147,
#           "hex": "88283082a9fffff"
#         },
#         {
#           "count": 192,
#           "hex": "882830828bfffff"
#         },
#         {
#           "count": 376,
#           "hex": "8828308287fffff"
#         },
#         {
#           "count": 88,
#           "hex": "88283082e3fffff"
#         },
#         {
#           "count": 34,
#           "hex": "88283082adfffff"
#         },
#         {
#           "count": 150,
#           "hex": "8828308285fffff"
#         },
#         {
#           "count": 16,
#           "hex": "88283080c9fffff"
#         },
#         {
#           "count": 16,
#           "hex": "88283082b3fffff"
#         },
#         {
#           "count": 46,
#           "hex": "8828309511fffff"
#         },
#         {
#           "count": 452,
#           "hex": "8828308289fffff"
#         },
#         {
#           "count": 160,
#           "hex": "882830828dfffff"
#         },
#         {
#           "count": 184,
#           "hex": "8828308283fffff"
#         },
#         {
#           "count": 108,
#           "hex": "882830829dfffff"
#         },
#         {
#           "count": 314,
#           "hex": "88283082c3fffff"
#         },
#         {
#           "count": 430,
#           "hex": "88283082abfffff"
#         },
#         {
#           "count": 86,
#           "hex": "88283095a9fffff"
#         },
#         {
#           "count": 42,
#           "hex": "8828309515fffff"
#         },
#         {
#           "count": 420,
#           "hex": "88283082a3fffff"
#         },
#         {
#           "count": 44,
#           "hex": "88283095adfffff"
#         },
#         {
#           "count": 10,
#           "hex": "882830821dfffff"
#         },
#         {
#           "count": 176,
#           "hex": "8828308295fffff"
#         },
#         {
#           "count": 80,
#           "hex": "8828308291fffff"
#         },
#         {
#           "count": 228,
#           "hex": "88283082d5fffff"
#         },
#         {
#           "count": 409,
#           "hex": "88283082c7fffff"
#         },
#         {
#           "count": 58,
#           "hex": "88283082edfffff"
#         },
#         {
#           "count": 52,
#           "hex": "8828308749fffff"
#         },
#         {
#           "count": 80,
#           "hex": "882830874dfffff"
#         },
#         {
#           "count": 16,
#           "hex": "88283082d1fffff"
#         },
#         {
#           "count": 20,
#           "hex": "8828309527fffff"
#         },
#         {
#           "count": 92,
#           "hex": "88283082ebfffff"
#         },
#         {
#           "count": 190,
#           "hex": "88283082bdfffff"
#         },
#         {
#           "count": 162,
#           "hex": "88283082a1fffff"
#         },
#         {
#           "count": 56,
#           "hex": "88283082ddfffff"
#         },
#         {
#           "count": 6,
#           "hex": "882830821bfffff"
#         },
#         {
#           "count": 96,
#           "hex": "88283082b5fffff"
#         },
#         {
#           "count": 136,
#           "hex": "88283082d3fffff"
#         },
#         {
#           "count": 14,
#           "hex": "8828309535fffff"
#         },
#         {
#           "count": 36,
#           "hex": "88283095e9fffff"
#         },
#         {
#           "count": 24,
#           "hex": "88283095ebfffff"
#         },
#         {
#           "count": 78,
#           "hex": "88283082c5fffff"
#         },
#         {
#           "count": 96,
#           "hex": "88283095a1fffff"
#         },
#         {
#           "count": 98,
#           "hex": "8828308299fffff"
#         },
#         {
#           "count": 24,
#           "hex": "882830953dfffff"
#         },
#         {
#           "count": 184,
#           "hex": "88283082e1fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828309533fffff"
#         },
#         {
#           "count": 80,
#           "hex": "88283082cbfffff"
#         },
#         {
#           "count": 2,
#           "hex": "882830951bfffff"
#         },
#         {
#           "count": 96,
#           "hex": "88283082c9fffff"
#         },
#         {
#           "count": 34,
#           "hex": "88283082e9fffff"
#         },
#         {
#           "count": 28,
#           "hex": "8828309507fffff"
#         },
#         {
#           "count": 14,
#           "hex": "88283095c7fffff"
#         },
#         {
#           "count": 88,
#           "hex": "88283082b1fffff"
#         },
#         {
#           "count": 44,
#           "hex": "88283095b5fffff"
#         },
#         {
#           "count": 10,
#           "hex": "8828309525fffff"
#         },
#         {
#           "count": 68,
#           "hex": "882830876dfffff"
#         },
#         {
#           "count": 44,
#           "hex": "88283082bbfffff"
#         },
#         {
#           "count": 14,
#           "hex": "88283095c3fffff"
#         },
#         {
#           "count": 4,
#           "hex": "88283095bdfffff"
#         },
#         {
#           "count": 48,
#           "hex": "88283082b7fffff"
#         },
#         {
#           "count": 8,
#           "hex": "88283095c5fffff"
#         },
#         {
#           "count": 6,
#           "hex": "8828309581fffff"
#         },
#         {
#           "count": 20,
#           "hex": "8828308297fffff"
#         },
#         {
#           "count": 16,
#           "hex": "88283082cdfffff"
#         },
#         {
#           "count": 230,
#           "hex": "88283082e7fffff"
#         },
#         {
#           "count": 2,
#           "hex": "8828309557fffff"
#         },
#         {
#           "count": 2,
#           "hex": "8828309505fffff"
#         },
#         {
#           "count": 4,
#           "hex": "882830952bfffff"
#         },
#         {
#           "count": 60,
#           "hex": "8828308253fffff"
#         },
#         {
#           "count": 24,
#           "hex": "88283095b1fffff"
#         },
#         {
#           "count": 14,
#           "hex": "882830958bfffff"
#         },
#         {
#           "count": 12,
#           "hex": "88283095e5fffff"
#         },
#         {
#           "count": 2,
#           "hex": "8828309519fffff"
#         },
#         {
#           "count": 40,
#           "hex": "8828308219fffff"
#         },
#         {
#           "count": 8,
#           "hex": "882830950bfffff"
#         },
#         {
#           "count": 28,
#           "hex": "88283095a5fffff"
#         },
#         {
#           "count": 2,
#           "hex": "88283095edfffff"
#         },
#         {
#           "count": 18,
#           "hex": "8828309587fffff"
#         },
#         {
#           "count": 8,
#           "hex": "8828308211fffff"
#         },
#         {
#           "count": 64,
#           "hex": "88283082a7fffff"
#         },
#         {
#           "count": 4,
#           "hex": "88283095e3fffff"
#         },
#         {
#           "count": 2,
#           "hex": "882830958dfffff"
#         },
#         {
#           "count": 16,
#           "hex": "88283095abfffff"
#         },
#         {
#           "count": 2,
#           "hex": "88283082a5fffff"
#         },
#         {
#           "count": 16,
#           "hex": "8828309585fffff"
#         },
#         {
#           "count": 74,
#           "hex": "8828308293fffff"
#         },
#         {
#           "count": 2,
#           "hex": "8828309583fffff"
#         },
#         {
#           "count": 84,
#           "hex": "882830959dfffff"
#         },
#         {
#           "count": 22,
#           "hex": "88283095a7fffff"
#         },
#         {
#           "count": 16,
#           "hex": "882830829bfffff"
#         },
#         {
#           "count": 2,
#           "hex": "88283095cdfffff"
#         },
#         {
#           "count": 2,
#           "hex": "8828309509fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828308215fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828308769fffff"
#         },
#         {
#           "count": 14,
#           "hex": "8828309501fffff"
#         },
#         {
#           "count": 24,
#           "hex": "88283095ddfffff"
#         },
#         {
#           "count": 18,
#           "hex": "8828309523fffff"
#         },
#         {
#           "count": 6,
#           "hex": "88283095a3fffff"
#         },
#         {
#           "count": 24,
#           "hex": "8828309565fffff"
#         },
#         {
#           "count": 16,
#           "hex": "8828309567fffff"
#         },
#         {
#           "count": 28,
#           "hex": "88283095cbfffff"
#         },
#         {
#           "count": 12,
#           "hex": "8828309539fffff"
#         },
#         {
#           "count": 10,
#           "hex": "8828309503fffff"
#         },
#         {
#           "count": 28,
#           "hex": "8828309597fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828309537fffff"
#         },
#         {
#           "count": 4,
#           "hex": "88283095d7fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828309591fffff"
#         },
#         {
#           "count": 2,
#           "hex": "88283080cbfffff"
#         },
#         {
#           "count": 14,
#           "hex": "8828309513fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828308217fffff"
#         },
#         {
#           "count": 18,
#           "hex": "8828308257fffff"
#         },
#         {
#           "count": 10,
#           "hex": "88283095e7fffff"
#         },
#         {
#           "count": 16,
#           "hex": "88283095bbfffff"
#         },
#         {
#           "count": 2,
#           "hex": "882830950dfffff"
#         },
#         {
#           "count": 6,
#           "hex": "8828308213fffff"
#         },
#         {
#           "count": 13,
#           "hex": "88283095b9fffff"
#         },
#         {
#           "count": 2,
#           "hex": "8828309563fffff"
#         },
#         {
#           "count": 4,
#           "hex": "8828309589fffff"
#         },
#         {
#           "count": 4,
#           "hex": "882830820bfffff"
#         },
#         {
#           "count": 4,
#           "hex": "88283095c1fffff"
#         },
#         {
#           "count": 8,
#           "hex": "88283095e1fffff"
#         }
#       ],
#       "extruded": false,
#       "filled": true,
#       "getFillColor": "@@=[255 - count, 255, count]",
#       "getHexagon": "@@=hex",
#       "getLineColor": [
#         255,
#         255,
#         255
#       ],
#       "id": "b3e3c0d4-d699-4e72-b2ed-32aa72d8b905",
#       "lineWidthMinPixels": 2,
#       "pickable": true,
#       "stroked": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %%
df['center'] = df['hex'].map(lambda x: h3.h3_to_geo(x))
df['boundary'] = df['hex'].map(lambda x: h3.h3_to_geo_boundary(x))

# %%
from folium import Map, CircleMarker, Polygon

m = Map(location=[37.7, -122.4], zoom_start=11)

for idx, row in df.iterrows():
    CircleMarker(location=[row['center'][0], row['center'][1]],
                 fill=True, radius=2, color='red').add_to(m)
    Polygon(locations=row['boundary']).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fc6341f36b7a0ea678708fb8eb2719f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fc6341f36b7a0ea678708fb8eb2719f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_2fc6341f36b7a0ea678708fb8eb2719f = L.map(
#                 &quot;map_2fc6341f36b7a0ea678708fb8eb2719f&quot;,
#                 {
#                     center: [37.7, -122.4],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74560ab3a10544918679a2e605f0daac = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2fc6341f36b7a0ea678708fb8eb2719f);
#
#
#             var circle_marker_61f8b58991b620cb61eecd8968b5cf44 = L.circleMarker(
#                 [37.78758972240419, -122.42261514007359],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2fc6341f36b7a0ea678708fb8eb2719f);
#
#
#             var polygon_012dba27d8827cb47406f60203ab2cbe = L.polygon(
#                 [[37.78289841436256, -122.42116698852692], [37.786441773353644, -122.41669307951518], [37.7911330575155, -122.41814112039496], [37.79228079669274, -122.42406340880041], [37.78873732075713, -122.4285371044262], [37.78404622259876, -122.42708872508095]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2fc6341f36b7a0ea678708fb8eb2719f);
#
#
#             var circle_marker_386cd10505936c13aa4758006e35b835 = L.circleMarker(
#                 [37.77351509723813, -122.41827103692466],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2fc6341f36b7a0ea678708fb8eb2719f);
#
#
#             var polygon_e708d0ba460b212fad58196efe1b51a8 = L.polygon(
#                 [[37.768823088264455, -122.41682323684428], [37.77236651869775, -122.41234965984782], [37.77705850389022, -122.41379734925398], [37.77820687262237, -122.41971895414805], [37.77466332517581, -122.42419231791122], [37.7699715260203, -122.42274429006201]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2fc6341f36b7a0ea678708fb8eb2719f);
#
#
#             var circle_marker_1f38d7f9782773dc2ffbeab350bd18ba = L.circleMarker(
#                 [37.768723332810424, -122.4390582784092],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_2fc6341f36b7a0ea678708fb8eb2719f);
#
#
#             var polygon_de94339628822b94db40bf65c192816b = L.polygon(
#                 [[37.764031696110386, -122.43760980181288], [37.76757573682727, -122.43313774173482], [37.772267349851525, -122.43458610784572], [37.77341473594332, -122.44050687216347], [37.769870578286934, -122.44497871857398], [37.76517915148818, -122.4435300143827]],

# %%
# 데이터 로드
df = pd.read_csv('https://github.com/fivethirtyeight/uber-tlc-foil-response/raw/master/uber-trip-data/uber-raw-data-apr14.csv')

# 데이터셋 확인
print(df.head())
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %% [markdown]
# - Date/Time: 여행이 시작된 날짜와 시간 정보. 예를 들어, 4/1/2014 0:11:00는 2014년 4월 1일 오전 0시 11분에 시작된 여행을 의미합니다.
# - Lat: 출발지의 위도 정보. 위도는 지구의 남북 위치를 나타내는 수치입니다.
# - Lon: 출발지의 경도 정보. 경도는 지구의 동서 위치를 나타내는 수치입니다.
# - Base: Uber의 서비스를 제공하는 특정 "베이스 코드"가 포함되어 있습니다. 이 코드는 보통 특정 Uber 서비스 센터 또는 운영 지역을 나타냅니다.

# %%
df.describe()
# Out:
#                  Lat            Lon
# count  564516.000000  564516.000000
# mean       40.740005     -73.976817
# std         0.036083       0.050426
# min        40.072900     -74.773300
# 25%        40.722500     -73.997700
# 50%        40.742500     -73.984800
# 75%        40.760700     -73.970000
# max        42.116600     -72.066600

# %% [markdown]
# ### 1. 데이터의 기본적인 indexing 및 slicing

# %%
# 처음 5개의 행을 출력
print(df.head())
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
# 'Lat' 열의 값만 출력
print(df['Lat'])
# Out:
# 0         40.7690
# 1         40.7267
# 2         40.7316
# 3         40.7588
# 4         40.7594
#            ...
# 564511    40.7640
# 564512    40.7629
# 564513    40.7443
# 564514    40.6756
# 564515    40.6880
# Name: Lat, Length: 564516, dtype: float64

# %%
# 10행부터 20행까지 출력
print(df.iloc[10:21])
# Out:
#            Date/Time      Lat      Lon    Base
# 10  4/1/2014 1:19:00  40.7256 -73.9869  B02512
# 11  4/1/2014 1:48:00  40.7591 -73.9684  B02512
# 12  4/1/2014 1:49:00  40.7271 -73.9803  B02512
# 13  4/1/2014 2:11:00  40.6463 -73.7896  B02512
# 14  4/1/2014 2:25:00  40.7564 -73.9167  B02512
# 15  4/1/2014 2:31:00  40.7666 -73.9531  B02512
# 16  4/1/2014 2:43:00  40.7580 -73.9761  B02512
# 17  4/1/2014 3:22:00  40.7238 -73.9821  B02512
# 18  4/1/2014 3:35:00  40.7531 -74.0039  B02512
# 19  4/1/2014 3:35:00  40.7389 -74.0393  B02512
# 20  4/1/2014 3:41:00  40.7619 -73.9715  B02512

# %%
# Base 갯수 확인
df.Base.value_counts()
# Out:
# B02682    227808
# B02598    183263
# B02617    108001
# B02512     35536
# B02764      9908
# Name: Base, dtype: int64

# %% [markdown]
# ### 2. 결측치에 대한 처리

# %%
# 결측치 개수 확인
print(df.isnull().sum())
# Out:
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %% [markdown]
# ### 3. 기초적인 통계 추출 및 분석

# %%
# 데이터 요약
print(df.describe())

# 'Lat' 열의 평균
print(df['Lat'].mean())

# 'Lon' 열의 중앙값
print(df['Lon'].median())

# 'Base' 열에서 각 값의 빈도수 출력
print(df['Base'].value_counts())
# Out:
#                  Lat            Lon
# count  564516.000000  564516.000000
# mean       40.740005     -73.976817
# std         0.036083       0.050426
# min        40.072900     -74.773300
# 25%        40.722500     -73.997700
# 50%        40.742500     -73.984800
# 75%        40.760700     -73.970000
# max        42.116600     -72.066600
# 40.74000520746974
# -73.9848
# B02682    227808
# B02598    183263
# B02617    108001
# B02512     35536
# B02764      9908
# Name: Base, dtype: int64

# %% [markdown]
# ### 4. 데이터에 대한 질문을 던져보고 해답을 찾기

# %%
df['Date/Time'] = pd.to_datetime(df['Date/Time'])

df['day_name'] = df['Date/Time'].dt.day_name()
df['month'] = df['Date/Time'].dt.month
df['hour'] = df['Date/Time'].dt.hour

# %%
df
# Out:
#                  Date/Time      Lat      Lon    Base   day_name  month  hour
# 0      2014-04-01 00:11:00  40.7690 -73.9549  B02512    Tuesday      4     0
# 1      2014-04-01 00:17:00  40.7267 -74.0345  B02512    Tuesday      4     0
# 2      2014-04-01 00:21:00  40.7316 -73.9873  B02512    Tuesday      4     0
# 3      2014-04-01 00:28:00  40.7588 -73.9776  B02512    Tuesday      4     0
# 4      2014-04-01 00:33:00  40.7594 -73.9722  B02512    Tuesday      4     0
# ...                    ...      ...      ...     ...        ...    ...   ...
# 564511 2014-04-30 23:22:00  40.7640 -73.9744  B02764  Wednesday      4    23
# 564512 2014-04-30 23:26:00  40.7629 -73.9672  B02764  Wednesday      4    23
# 564513 2014-04-30 23:31:00  40.7443 -73.9889  B02764  Wednesday      4    23
# 564514 2014-04-30 23:32:00  40.6756 -73.9405  B02764  Wednesday      4    23
# 564515 2014-04-30 23:48:00  40.6880 -73.9608  B02764  Wednesday      4    23
#
# [564516 rows x 7 columns]

# %% [markdown]
# ### 4.1 월별/요일별 Uber 이용량 비교
# - 가장 Uber 이용량이 많은 요일은 언제일까요?

# %%
uber_weekday = df.groupby(['month', 'day_name']).size().reset_index(level=[0, 1])
uber_weekday.columns = ['month', 'day_name', 'count']

uber_weekday = uber_weekday.sort_values('count', ascending=False)
uber_weekday
# Out:
#    month   day_name   count
# 6      4  Wednesday  108631
# 5      4    Tuesday   91185
# 0      4     Friday   90303
# 4      4   Thursday   85067
# 2      4   Saturday   77218
# 1      4     Monday   60861
# 3      4     Sunday   51251

# %% [markdown]
# ### 4.2 시간대별 이용량 비교
# - 가장 이용량이 많은 시간대는 언제일까요?

# %%
df['hour'].value_counts().sort_index()
# Out:
# 0     11910
# 1      7769
# 2      4935
# 3      5040
# 4      6095
# 5      9476
# 6     18498
# 7     24924
# 8     22843
# 9     17939
# 10    17865
# 11    18774
# 12    19425
# 13    22603
# 14    27190
# 15    35324
# 16    42003
# 17    45475
# 18    43003
# 19    38923
# 20    36244
# 21    36964
# 22    30645
# 23    20649
# Name: hour, dtype: int64

# %% [markdown]
# ### 4.3 Uber 수요에 대한 공간적인 시각화
# - 가장 수요가 많은 지역은 어디일까요?
# - 시간대/지역별로 수요의 변화를 나타내보고, 시사점을 도출해 봅시다

# %%
df['hex'] = df.apply(lambda x: h3.geo_to_h3(x['Lat'], x['Lon'], 5), axis=1)

# %%
df_hex_count = df[['hex']].value_counts().reset_index()
df_hex_count.columns = ['hex', 'count']

layer = pdk.Layer(
    "H3HexagonLayer",
    df_hex_count,
    pickable=True,
    stroked=True,
    filled=True,
    extruded=False,
    get_hexagon="hex",
    get_fill_color="[255 - count, 0, count]",
    get_line_color=[255, 255, 255],
    opacity=0.2,
    coverage=0.9,
    line_width_min_pixels=2,
)

view_state = pdk.ViewState(latitude=40.8, longitude=-73.6, zoom=7)
r = pdk.Deck(layers=[layer], initial_view_state=view_state, tooltip={"text": "Count: {count}"})

r

### New York 부근이 가장 수요가 많음
# Out:
# {
#   "initialViewState": {
#     "latitude": 40.8,
#     "longitude": -73.6,
#     "zoom": 7
#   },
#   "layers": [
#     {
#       "@@type": "H3HexagonLayer",
#       "coverage": 0.9,
#       "data": [
#         {
#           "count": 248946,
#           "hex": "852a100ffffffff"
#         },
#         {
#           "count": 243979,
#           "hex": "852a1073fffffff"
#         },
#         {
#           "count": 43307,
#           "hex": "852a100bfffffff"
#         },
#         {
#           "count": 11796,
#           "hex": "852a103bfffffff"
#         },
#         {
#           "count": 11747,
#           "hex": "852a1077fffffff"
#         },
#         {
#           "count": 1172,
#           "hex": "852a1003fffffff"
#         },
#         {
#           "count": 1044,
#           "hex": "852a1007fffffff"
#         },
#         {
#           "count": 365,
#           "hex": "852a1013fffffff"
#         },
#         {
#           "count": 351,
#           "hex": "852a107bfffffff"
#         },
#         {
#           "count": 311,
#           "hex": "852a101bfffffff"
#         },
#         {
#           "count": 308,
#           "hex": "852a1047fffffff"
#         },
#         {
#           "count": 150,
#           "hex": "852a1063fffffff"
#         },
#         {
#           "count": 135,
#           "hex": "852a10abfffffff"
#         },
#         {
#           "count": 108,
#           "hex": "852a104ffffffff"
#         },
#         {
#           "count": 106,
#           "hex": "852a1057fffffff"
#         },
#         {
#           "count": 89,
#           "hex": "852a10c7fffffff"
#         },
#         {
#           "count": 79,
#           "hex": "852a108ffffffff"
#         },
#         {
#           "count": 67,
#           "hex": "852a106bfffffff"
#         },
#         {
#           "count": 63,
#           "hex": "852a108bfffffff"
#         },
#         {
#           "count": 60,
#           "hex": "852a1017fffffff"
#         },
#         {
#           "count": 53,
#           "hex": "852a1033fffffff"
#         },
#         {
#           "count": 31,
#           "hex": "852a13d3fffffff"
#         },
#         {
#           "count": 28,
#           "hex": "852a1083fffffff"
#         },
#         {
#           "count": 25,
#           "hex": "852a12b7fffffff"
#         },
#         {
#           "count": 24,
#           "hex": "852a10a3fffffff"
#         },
#         {
#           "count": 22,
#           "hex": "852a106ffffffff"
#         },
#         {
#           "count": 20,
#           "hex": "852a12a7fffffff"
#         },
#         {
#           "count": 16,
#           "hex": "852a1043fffffff"
#         },
#         {
#           "count": 15,
#           "hex": "852a10bbfffffff"
#         },
#         {
#           "count": 12,
#           "hex": "852a1097fffffff"
#         },
#         {
#           "count": 11,
#           "hex": "852a1053fffffff"
#         },
#         {
#           "count": 11,
#           "hex": "852a10cffffffff"
#         },
#         {
#           "count": 9,
#           "hex": "852a13c3fffffff"
#         },
#         {
#           "count": 9,
#           "hex": "852a10b3fffffff"
#         },
#         {
#           "count": 6,
#           "hex": "852a10d7fffffff"
#         },
#         {
#           "count": 4,
#           "hex": "852a12a3fffffff"
#         },
#         {
#           "count": 4,
#           "hex": "852a10b7fffffff"
#         },
#         {
#           "count": 3,
#           "hex": "852a1433fffffff"
#         },
#         {
#           "count": 3,
#           "hex": "852a13cffffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a10dbfffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a1547fffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a142ffffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a1393fffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a139bfffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a1427fffffff"
#         },
#         {
#           "count": 2,
#           "hex": "852a13dbfffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a10cbfffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a13d7fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a1637fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a1423fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a1093fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a104bfffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a13c7fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a10c3fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a138ffffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a1383fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a109bfffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a10d3fffffff"
#         },
#         {
#           "count": 1,
#           "hex": "852a3353fffffff"
#         }
#       ],
#       "extruded": false,
#       "filled": true,
#       "getFillColor": "@@=[255 - count, 0, count]",
#       "getHexagon": "@@=hex",
#       "getLineColor": [
#         255,
#         255,
#         255
#       ],
#       "id": "27f83bea-e592-404d-93f4-228b56a5a142",
#       "lineWidthMinPixels": 2,
#       "opacity": 0.2,
#       "pickable": true,
#       "stroked": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }

# %%
from IPython.display import display, clear_output
import ipywidgets as widgets
import time

slider = widgets.IntSlider(0, min=1, max=23, step=1)

df_hour_region = df[['hour', 'hex']].groupby(['hour', 'hex']).size().reset_index(level=[0, 1])
df_hour_region.columns = ['hour', 'hex', 'count']

view_state = pdk.ViewState(latitude=40.8, longitude=-73.6, zoom=7)

layer = pdk.Layer(
    "H3HexagonLayer",
    df_hour_region,
    pickable=True,
    stroked=True,
    filled=True,
    extruded=False,
    get_hexagon="hex",
    get_fill_color="[255 - count, 0, count]",
    get_line_color=[255, 255, 255],
    opacity=0.2,
    coverage=0.9,
    line_width_min_pixels=2,
)
def on_change(v):
    results = df_hour_region.loc[df_hour_region['hour'] == int(v)].to_dict('records')
    layer.data = results
    r.update()
    clear_output()
    display(r)
    time.sleep(3)

r = pdk.Deck(layers=[layer], initial_view_state=view_state, tooltip={"text": "Count: {count}"})
display(r)

while True:
    for t in range(0, 24):
        on_change(t)

# slider.observe(on_change, names='value')
# display(slider)

### 제 컴퓨터에서만 안되는건지 pydeck update 함수가 동작하지 않아
### clear output 함수를 활용했습니다.
# Out:
# {
#   "initialViewState": {
#     "latitude": 40.8,
#     "longitude": -73.6,
#     "zoom": 7
#   },
#   "layers": [
#     {
#       "@@type": "H3HexagonLayer",
#       "coverage": 0.9,
#       "data": [
#         {
#           "count": 21,
#           "hex": "852a1003fffffff",
#           "hour": 1
#         },
#         {
#           "count": 12,
#           "hex": "852a1007fffffff",
#           "hour": 1
#         },
#         {
#           "count": 284,
#           "hex": "852a100bfffffff",
#           "hour": 1
#         },
#         {
#           "count": 2588,
#           "hex": "852a100ffffffff",
#           "hour": 1
#         },
#         {
#           "count": 2,
#           "hex": "852a1013fffffff",
#           "hour": 1
#         },
#         {
#           "count": 5,
#           "hex": "852a101bfffffff",
#           "hour": 1
#         },
#         {
#           "count": 3,
#           "hex": "852a1033fffffff",
#           "hour": 1
#         },
#         {
#           "count": 30,
#           "hex": "852a103bfffffff",
#           "hour": 1
#         },
#         {
#           "count": 1,
#           "hex": "852a1043fffffff",
#           "hour": 1
#         },
#         {
#           "count": 4,
#           "hex": "852a1047fffffff",
#           "hour": 1
#         },
#         {
#           "count": 1,
#           "hex": "852a104ffffffff",
#           "hour": 1
#         },
#         {
#           "count": 1,
#           "hex": "852a1057fffffff",
#           "hour": 1
#         },
#         {
#           "count": 2,
#           "hex": "852a1063fffffff",
#           "hour": 1
#         },
#         {
#           "count": 1,
#           "hex": "852a106bfffffff",
#           "hour": 1
#         },
#         {
#           "count": 2,
#           "hex": "852a106ffffffff",
#           "hour": 1
#         },
#         {
#           "count": 4632,
#           "hex": "852a1073fffffff",
#           "hour": 1
#         },
#         {
#           "count": 171,
#           "hex": "852a1077fffffff",
#           "hour": 1
#         },
#         {
#           "count": 6,
#           "hex": "852a107bfffffff",
#           "hour": 1
#         },
#         {
#           "count": 1,
#           "hex": "852a10abfffffff",
#           "hour": 1
#         },
#         {
#           "count": 2,
#           "hex": "852a13d3fffffff",
#           "hour": 1
#         }
#       ],
#       "extruded": false,
#       "filled": true,
#       "getFillColor": "@@=[255 - count, 0, count]",
#       "getHexagon": "@@=hex",
#       "getLineColor": [
#         255,
#         255,
#         255
#       ],
#       "id": "02c405a4-5e77-41e2-aa99-311e6624c734",
#       "lineWidthMinPixels": 2,
#       "opacity": 0.2,
#       "pickable": true,
#       "stroked": true
#     }
#   ],
#   "mapProvider": "carto",
#   "mapStyle": "https://basemaps.cartocdn.com/gl/dark-matter-gl-style/style.json",
#   "views": [
#     {
#       "@@type": "MapView",
#       "controller": true
#     }
#   ]
# }
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 39
#      37 while True:
#      38     for t in range(0, 24):
# ---> 39         on_change(t)
#
# Cell In[19], line 32, in on_change(v)
#      30 clear_output()
#      31 display(r)
# ---> 32 time.sleep(3)
#
# KeyboardInterrupt:
